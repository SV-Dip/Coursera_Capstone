# %% [markdown]
# # Best Neighbourhood to Open Steakhouse in Toronto

# %% [markdown]
# Finding the best Neighbourhood in Toronto using Data Science
#
#
#
# **Segment and Cluster Neighborhoods in Toronto, Ontario to find best neighborhood to open steakhouse**
#
# *Author: Subha Halder*
#
# ===========================================

# %% [markdown]
# # Introduction: Business Problem

# %% [markdown]
# In this project, we are going to look for an optimal location to open a steakhouse. Specifically, this report can provide a reference for stakeholders who are interested in opening a steakhouse in Toronto, Ontario, Canada.

# %% [markdown]
# Toronto, the capital of the province of Ontario, is a major Canadian city along Lake Ontario’s northwestern shore. It's a dynamic metropolis with a core of soaring skyscrapers, all dwarfed by the iconic, free-standing CN Tower.

# %% [markdown]
# ### Why open business in Toronto?

# %% [markdown]
# 1. Capital of Ontario province and a major city in North America
# 2. Toronto is sixth safest city
# 3. Toronto along with Montreal are the top two best places to live in the world according to an index of city rankings compiled by The Economist
# 4. Toronto has a population of 2.7M and monthly household income of CAD 65,829

# %% [markdown]
# This report will perticularly focus on opening a steakhouse in Toronto City
#
# There are many restaurants on Toronto, we will conclude where are the existing restaurants. Then we will use a clustering model to find similar areas in city considering demographic data of each borough and region. The preferred area shall be area with most popular venues and population density with monthly household income.

# %% [markdown]
# We will use data science tools to fetch the raw data, visualize it then generate a few most promising areas based on the above criteria. In the meanwhile, we will also explain the advantage and traits for the candidates, so that stakeholders can make the final decision base on the analysis.

# %% [markdown]
# # Data Requirement

# %% [markdown]
# Based on the definition of our problem, factors that may impact our decision are:
#
# 1. Demographic information, e.g. population, density, age, median household income
# 2. Number of existing popular venues
# 3. Number of existing restaurants/steakhouses
#
# In this project, we will fetch or extract data from the following data sources:
#
# 1. Toronto city neighbourhood census data collected from Toronto Open Portal: https://Toronto.ca
# 2. Age Demigraphic for Restaurants: https://scholarsarchive.jwu.edu/cgi/viewcontent.cgi?article=1008&context=mba_student
# 3. Toronto city postal codes: https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M
# 4. Latitude Longitude Data from Geocoder API
# 5. Data for venue names, venue category, location from Foursquare
# 6. Toronto City GeoJSON file from: https://github.com/jasonicarter/toronto-geojson
#
# Collected Data-heads:

# %% [markdown]
# **Toronto Census Data**
# /////////////////////////////////////////////////////////////////////////////////////////

# %%
from IPython.display import Image
Image(filename = "/Users/NabanitaHalder/Projects/png/1.png", width = 900)

# %% [markdown]
# **GeoJSON File**
# /////////////////////////////////////////////////////////////////////////////////////////

# %%
Image(filename = "/Users/NabanitaHalder/Projects/png/10.png", width = 900)

# %% [markdown]
# **Choropleth Map: Density**
# /////////////////////////////////////////////////////////////////////////////////////////

# %%
Image(filename = "/Users/NabanitaHalder/Projects/png/2.png", width = 900)

# %% [raw]
# We can see that Density Map can be generated with GeoJson file and Census Data.
#
# And Area with highest population density is North St. James Town

# %%
Image(filename = "/Users/NabanitaHalder/Projects/png/3.png", width = 800)

# %% [markdown]
# **Choropleth Map: Median Household Income**
# /////////////////////////////////////////////////////////////////////////////////////////

# %%
Image(filename = "/Users/NabanitaHalder/Projects/png/4.png", width = 900)

# %% [markdown]
# Area with highest median household income is Bridle Path-Sunnybrook-York Mills

# %%
Image(filename = "/Users/NabanitaHalder/Projects/png/5.png", width = 800)

# %% [markdown]
# **Age Demigraphic for Restaurants**
# /////////////////////////////////////////////////////////////////////////////////////////

# %% [markdown]
# Working age demographic tends to spend more on outdoor dining. dataframe and bar chart shown for spending frequency of every age group.

# %%
Image(filename = "/Users/NabanitaHalder/Projects/png/6.png", width = 400)

# %%
Image(filename = "/Users/NabanitaHalder/Projects/png/7.png", width = 450)

# %% [markdown]
# **Toronto city postal codes & Location Data from Geocoder API**
# /////////////////////////////////////////////////////////////////////////////////////////

# %%
Image(filename = "/Users/NabanitaHalder/Projects/png/8.png", width = 600)

# %% [markdown]
# **Data for venue names, venue category, location from Foursquare**
# /////////////////////////////////////////////////////////////////////////////////////////

# %%
Image(filename = "/Users/NabanitaHalder/Projects/png/9.png", width = 900)

# %% [markdown]
# So far, we retrieved all the necessary raw data we needed and visualized them. In the next notebook names , we will manipulate these datasets, extract data, and generate new features for the machine learning algorithm. Finally, we will find out the best suitable place to open a steakhouse in Toronto.

# %% [markdown]
# **Thank You**
#
# Date: 31st Oct, 2020
#
# *Author: Subha Halder*
